# %%
import pandas as pd
import numpy as np

# %%
titanic_df= pd.read_csv("titanic.csv", sep=",")

# %% [markdown]
# # 1) Summary of dataset

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 887 entries, 0 to 886
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Survived                 887 non-null    int64
#  1   Pclass                   887 non-null    int64
#  2   Name                     887 non-null    object
#  3   Sex                      887 non-null    object
#  4   Age                      887 non-null    float64
#  5   Siblings/Spouses Aboard  887 non-null    int64
#  6   Parents/Children Aboard  887 non-null    int64
#  7   Fare                     887 non-null    float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.6+ KB

# %% [markdown]
# # 2) Extract column labels, shape and data types

# %%
list(titanic_df)
# Out:
# ['Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'Siblings/Spouses Aboard',
#  'Parents/Children Aboard',
#  'Fare']

# %%
titanic_df.shape
# Out:
# (887, 8)

# %%
titanic_df

# %% [markdown]
# # 3) Pivot tables

# %%
titanic_df.pivot_table(index=["Sex", "Age"])
# Out:
#                    Fare  Parents/Children Aboard    Pclass  \
# Sex    Age
# female 0.75   19.258300                 1.000000  3.000000
#        1.00   13.437500                 1.500000  3.000000
#        2.00   40.261900                 1.428571  2.571429
#        3.00   29.373633                 1.333333  2.666667
#        4.00   22.828340                 1.200000  2.600000
# ...                 ...                      ...       ...
# male   70.00  40.750000                 0.500000  1.500000
#        70.50   7.750000                 0.000000  3.000000
#        71.00  42.079200                 0.000000  1.000000
#        74.00   7.775000                 0.000000  3.000000
#        80.00  30.000000                 0.000000  1.000000
#
#               Siblings/Spouses Aboard  Survived
# Sex    Age
# female 0.75                  2.000000  1.000000
#        1.00                  0.500000  1.000000
#        2.00                  1.428571  0.428571
#        3.00                  2.333333  0.333333
#        4.00                  0.800000  1.000000
# ...                               ...       ...
# male   70.00                 0.500000  0.000000
#        70.50                 0.000000  0.000000
#        71.00                 0.000000  0.000000
#        74.00                 0.000000  0.000000
#        80.00                 0.000000  1.000000
#
# [149 rows x 5 columns]

# %%
titanic_df.pivot_table(index=["Sex", "Pclass"])
# Out:
#                      Age        Fare  Parents/Children Aboard  \
# Sex    Pclass
# female 1       35.255319  106.125798                 0.457447
#        2       28.980263   21.970121                 0.605263
#        3       22.135417   16.118810                 0.798611
# male   1       41.511639   67.226127                 0.278689
#        2       30.493796   19.741782                 0.222222
#        3       26.470612   12.695466                 0.227405
#
#                Siblings/Spouses Aboard  Survived
# Sex    Pclass
# female 1                      0.553191  0.968085
#        2                      0.486842  0.921053
#        3                      0.895833  0.500000
# male   1                      0.311475  0.368852
#        2                      0.342593  0.157407
#        3                      0.504373  0.137026

# %%
titanic_df.pivot_table(index=["Sex", "Pclass"])
# Out:
#                      Age        Fare  Parents/Children Aboard  \
# Sex    Pclass
# female 1       35.255319  106.125798                 0.457447
#        2       28.980263   21.970121                 0.605263
#        3       22.135417   16.118810                 0.798611
# male   1       41.511639   67.226127                 0.278689
#        2       30.493796   19.741782                 0.222222
#        3       26.470612   12.695466                 0.227405
#
#                Siblings/Spouses Aboard  Survived
# Sex    Pclass
# female 1                      0.553191  0.968085
#        2                      0.486842  0.921053
#        3                      0.895833  0.500000
# male   1                      0.311475  0.368852
#        2                      0.342593  0.157407
#        3                      0.504373  0.137026

# %%
titanic_df.pivot_table(index=["Sex", "Survived"])
# Out:
#                        Age       Fare  Parents/Children Aboard    Pclass  \
# Sex    Survived
# female 0         24.419753  23.024385                 1.037037  2.851852
#        1         28.866953  51.938573                 0.515021  1.918455
# male   0         31.136853  22.066170                 0.209052  2.471983
#        1         27.428165  40.821484                 0.357798  2.018349
#
#                  Siblings/Spouses Aboard
# Sex    Survived
# female 0                        1.209877
#        1                        0.515021
# male   0                        0.443966
#        1                        0.385321

# %% [markdown]
# # 4) Partition passengers in four categories based on age

# %%
titanic_df.pivot_table(index="Age", columns=["Sex"])
# Out:
#           Fare           Parents/Children Aboard      Pclass       \
# Sex     female      male                  female male female male
# Age
# 0.42       NaN    8.5167                     NaN  1.0    NaN  3.0
# 0.67       NaN   14.5000                     NaN  1.0    NaN  2.0
# 0.75   19.2583       NaN                     1.0  NaN    3.0  NaN
# 0.83       NaN   23.8750                     NaN  1.5    NaN  2.0
# 0.92       NaN  151.5500                     NaN  2.0    NaN  1.0
# ...        ...       ...                     ...  ...    ...  ...
# 70.00      NaN   40.7500                     NaN  0.5    NaN  1.5
# 70.50      NaN    7.7500                     NaN  0.0    NaN  3.0
# 71.00      NaN   42.0792                     NaN  0.0    NaN  1.0
# 74.00      NaN    7.7750                     NaN  0.0    NaN  3.0
# 80.00      NaN   30.0000                     NaN  0.0    NaN  1.0
#
#       Siblings/Spouses Aboard      Survived
# Sex                    female male   female male
# Age
# 0.42                      NaN  0.0      NaN  1.0
# 0.67                      NaN  1.0      NaN  1.0
# 0.75                      2.0  NaN      1.0  NaN
# 0.83                      NaN  0.5      NaN  1.0
# 0.92                      NaN  1.0      NaN  1.0
# ...                       ...  ...      ...  ...
# 70.00                     NaN  0.5      NaN  0.0
# 70.50                     NaN  0.0      NaN  0.0
# 71.00                     NaN  0.0      NaN  0.0
# 74.00                     NaN  0.0      NaN  0.0
# 80.00                     NaN  0.0      NaN  1.0
#
# [89 rows x 10 columns]

# %% [markdown]
# # 5) Pivot table and find number of adult male, female and children

# %%
titanic_df.pivot_table(index="Sex", columns="Sex", aggfunc="count", margins=True)
# Out:
#           Age               Fare               Name              \
# Sex    female   male  All female   male  All female   male  All
# Sex
# female  314.0    NaN  314  314.0    NaN  314  314.0    NaN  314
# male      NaN  573.0  573    NaN  573.0  573    NaN  573.0  573
# All     314.0  573.0  887  314.0  573.0  887  314.0  573.0  887
#
#        Parents/Children Aboard  ...      Pclass              \
# Sex                     female  ...  All female   male  All
# Sex                             ...
# female                   314.0  ...  314  314.0    NaN  314
# male                       NaN  ...  573    NaN  573.0  573
# All                      314.0  ...  887  314.0  573.0  887
#
#        Siblings/Spouses Aboard             Survived
# Sex                     female   male  All   female   male  All
# Sex
# female                   314.0    NaN  314    314.0    NaN  314
# male                       NaN  573.0  573      NaN  573.0  573
# All                      314.0  573.0  887    314.0  573.0  887
#
# [3 rows x 21 columns]

# %%
titanic_df["child"]= np.where(test["Age"]< 18, "yes", "no")

# %%
titanic_df.head(20)
# Out:
#     Survived  Pclass                                               Name  \
# 0          0       3                             Mr. Owen Harris Braund
# 1          1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2          1       3                              Miss. Laina Heikkinen
# 3          1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4          0       3                            Mr. William Henry Allen
# 5          0       3                                    Mr. James Moran
# 6          0       1                             Mr. Timothy J McCarthy
# 7          0       3                      Master. Gosta Leonard Palsson
# 8          1       3   Mrs. Oscar W (Elisabeth Vilhelmina Berg) Johnson
# 9          1       2                 Mrs. Nicholas (Adele Achem) Nasser
# 10         1       3                     Miss. Marguerite Rut Sandstrom
# 11         1       1                            Miss. Elizabeth Bonnell
# 12         0       3                      Mr. William Henry Saundercock
# 13         0       3                         Mr. Anders Johan Andersson
# 14         0       3                Miss. Hulda Amanda Adolfina Vestrom
# 15         1       2                     Mrs. (Mary D Kingcome) Hewlett
# 16         0       3                                Master. Eugene Rice
# 17         1       2                        Mr. Charles Eugene Williams
# 18         0       3  Mrs. Julius (Emelia Maria Vandemoortele) Vande...
# 19         1       3                             Mrs. Fatima Masselmani
#
#        Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare  \
# 0     male  22.0                        1                        0   7.2500
# 1   female  38.0                        1                        0  71.2833
# 2   female  26.0                        0                        0   7.9250
# 3   female  35.0                        1                        0  53.1000
# 4     male  35.0                        0                        0   8.0500
# 5     male  27.0                        0                        0   8.4583
# 6     male  54.0                        0                        0  51.8625
# 7     male   2.0                        3                        1  21.0750
# 8   female  27.0                        0                        2  11.1333
# 9   female  14.0                        1                        0  30.0708
# 10  female   4.0                        1                        1  16.7000
# 11  female  58.0                        0                        0  26.5500
# 12    male  20.0                        0                        0   8.0500
# 13    male  39.0                        1                        5  31.2750
# 14  female  14.0                        0                        0   7.8542
# 15  female  55.0                        0                        0  16.0000
# 16    male   2.0                        4                        1  29.1250
# 17    male  23.0                        0                        0  13.0000
# 18  female  31.0                        1                        0  18.0000
# 19  female  22.0                        0                        0   7.2250
#
#    child
# 0     no
# 1     no
# 2     no
# 3     no
# 4     no
# 5     no
# 6     no
# 7    yes
# 8     no
# 9    yes
# 10   yes
# 11    no
# 12    no
# 13    no
# 14   yes
# 15    no
# 16   yes
# 17    no
# 18    no
# 19    no
